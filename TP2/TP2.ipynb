# %%
import os
from collections import Counter
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import nltk
import json
import math

# %%
def lire_termes(fichier_descripteur):
    termes = []
    with open(fichier_descripteur, 'r', encoding='utf-8') as f:
        for ligne in f:
            _, terme = ligne.strip().split(' ', 1)  # On prend seulement le terme après le document
            termes.append(terme)
    return termes


# Fonction pour calculer la fréquence des termes dans tous les documents
def calculer_frequence_termes(documents):
    termes_tous_docs = []  # Liste de tous les termes dans tous les documents
    occurrences_termes_par_doc = {}  # Dictionnaire pour stocker les occurrences par document

    for doc in documents:
        fichier_descripteur = os.path.join(descripteur_path, f"{doc}_descripteur.txt")
        
        # Lire les termes du fichier descripteur
        termes = lire_termes(fichier_descripteur)
        
        # Ajouter les termes au total pour calculer la fréquence
        termes_tous_docs.extend(termes)
        
        # Compter les occurrences des termes dans chaque document
        occurrences_termes_par_doc[doc] = Counter(termes)
        print(occurrences_termes_par_doc[doc])

    # Calculer le nombre total de documents
    total_docs = len(documents)

    # Calculer la fréquence de chaque terme à travers tous les documents
    occurrences_totales = Counter(termes_tous_docs)
    frequence_termes = {terme: count / total_docs for terme, count in occurrences_totales.items()}

    return frequence_termes, occurrences_termes_par_doc


# Chemin vers le dossier descripteur
descripteur_path = '../TP1/Descripteurs'  # Remplacez par le chemin correct


documents = [doc.replace('_descripteur.txt', '') for doc in os.listdir(descripteur_path) if doc.endswith('_descripteur.txt')]

# Calculer les fréquences
frequence_termes, occurrences_termes_par_doc = calculer_frequence_termes(documents)

# Afficher les fréquences
for terme, freq in frequence_termes.items():
    print(f"Terme: {terme}, Fréquence: {freq:.4f}")

# mettre a jour les descripteur:
# Out:
# Terme: experiment, Fréquence: 0.3333
# Terme: investig, Fréquence: 0.3333
# Terme: aerodynam, Fréquence: 0.5000
# Terme: wing, Fréquence: 0.8333
# Terme: slipstream, Fréquence: 0.8333
# Terme: studi, Fréquence: 0.5000
# Terme: propel, Fréquence: 0.1667
# Terme: made, Fréquence: 0.5000
# Terme: order, Fréquence: 0.1667
# Terme: determin, Fréquence: 0.1667
# Terme: spanwis, Fréquence: 0.1667
# Terme: distribut, Fréquence: 0.8333
# Terme: lift, Fréquence: 1.0000
# Terme: increas, Fréquence: 0.3333
# Terme: due, Fréquence: 0.3333
# Terme: differ, Fréquence: 1.0000
# Terme: angl, Fréquence: 0.3333
# Terme: attack, Fréquence: 0.1667
# Terme: free, Fréquence: 0.8333
# Terme: stream, Fréquence: 1.1667
# Terme: veloc, Fréquence: 0.5000
# Terme: ratio, Fréquence: 0.5000
# Terme: result, Fréquence: 0.6667
# Terme: intend, Fréquence: 0.1667
# Terme: part, Fréquence: 0.3333
# Terme: evalu, Fréquence: 0.3333
# Terme: basi, Fréquence: 0.3333
# Terme: theoret, Fréquence: 0.1667
# Terme: treatment, Fréquence: 0.1667
# Terme: problem, Fréquence: 1.6667
# Terme: compar, Fréquence: 0.1667
# Terme: span, Fréquence: 0.1667
# Terme: load, Fréquence: 0.1667
# Terme: curv, Fréquence: 0.5000
# Terme: togeth, Fréquence: 0.1667
# Terme: support, Fréquence: 0.1667
# Terme: evid, Fréquence: 0.1667
# Terme: show, Fréquence: 0.5000
# Terme: substanti, Fréquence: 0.1667
# Terme: increment, Fréquence: 0.3333
# Terme: produc, Fréquence: 0.1667
# Terme: destal, Fréquence: 0.5000
# Terme: boundari, Fréquence: 3.3333
# Terme: layer, Fréquence: 3.3333
# Terme: control, Fréquence: 0.1667
# Terme: effect, Fréquence: 1.1667
# Terme: integr, Fréquence: 0.5000
# Terme: remain, Fréquence: 0.1667
# Terme: subtract, Fréquence: 0.1667
# Terme: found, Fréquence: 0.1667
# Terme: agre, Fréquence: 0.1667
# Terme: well, Fréquence: 0.1667
# Terme: potenti, Fréquence: 0.1667
# Terme: flow, Fréquence: 3.6667
# Terme: theori, Fréquence: 0.8333
# Terme: empir, Fréquence: 0.1667
# Terme: specif, Fréquence: 0.1667
# Terme: configur, Fréquence: 0.1667
# Terme: experi, Fréquence: 0.1667
# Terme: simpl, Fréquence: 0.6667
# Terme: shear, Fréquence: 0.6667
# Terme: past, Fréquence: 0.6667
# Terme: flat, Fréquence: 0.6667
# Terme: plate, Fréquence: 0.8333
# Terme: incompress, Fréquence: 0.6667
# Terme: fluid, Fréquence: 0.5000
# Terme: small, Fréquence: 0.3333
# Terme: viscos, Fréquence: 0.5000
# Terme: high, Fréquence: 0.1667
# Terme: speed, Fréquence: 0.8333
# Terme: viscou, Fréquence: 0.3333
# Terme: two, Fréquence: 1.0000
# Terme: dimension, Fréquence: 0.8333
# Terme: bodi, Fréquence: 1.5000
# Terme: usual, Fréquence: 0.3333
# Terme: necessari, Fréquence: 0.1667
# Terme: consid, Fréquence: 0.6667
# Terme: shock, Fréquence: 1.1667
# Terme: wave, Fréquence: 1.0000
# Terme: emit, Fréquence: 0.1667
# Terme: nose, Fréquence: 0.5000
# Terme: lead, Fréquence: 0.3333
# Terme: edg, Fréquence: 0.1667
# Terme: consequ, Fréquence: 0.3333
# Terme: exist, Fréquence: 0.1667
# Terme: inviscid, Fréquence: 0.5000
# Terme: rotat, Fréquence: 0.3333
# Terme: region, Fréquence: 0.3333
# Terme: situat, Fréquence: 0.3333
# Terme: aris, Fréquence: 0.1667
# Terme: instanc, Fréquence: 0.1667
# Terme: hyperson, Fréquence: 0.8333
# Terme: somewhat, Fréquence: 0.1667
# Terme: prandtl, Fréquence: 0.3333
# Terme: classic, Fréquence: 0.1667
# Terme: origin, Fréquence: 0.1667
# Terme: outsid, Fréquence: 0.1667
# Terme: irrot, Fréquence: 0.1667
# Terme: must, Fréquence: 0.1667
# Terme: possibl, Fréquence: 0.3333
# Terme: vortic, Fréquence: 0.5000
# Terme: recent, Fréquence: 0.1667
# Terme: discuss, Fréquence: 0.3333
# Terme: ferri, Fréquence: 0.1667
# Terme: libbi, Fréquence: 0.1667
# Terme: present, Fréquence: 0.5000
# Terme: paper, Fréquence: 0.1667
# Terme: shown, Fréquence: 0.1667
# Terme: treat, Fréquence: 0.3333
# Terme: approxim, Fréquence: 0.5000
# Terme: novel, Fréquence: 0.1667
# Terme: featur, Fréquence: 0.1667
# Terme: constant, Fréquence: 0.1667
# Terme: restrict, Fréquence: 0.1667
# Terme: steadi, Fréquence: 0.3333
# Terme: solut, Fréquence: 1.0000
# Terme: laminar, Fréquence: 0.1667
# Terme: equat, Fréquence: 0.8333
# Terme: thick, Fréquence: 0.1667
# Terme: skin, Fréquence: 0.1667
# Terme: friction, Fréquence: 0.1667
# Terme: obtain, Fréquence: 0.1667
# Terme: karman, Fréquence: 0.1667
# Terme: pohlhausen, Fréquence: 0.1667
# Terme: techniqu, Fréquence: 0.1667
# Terme: comparison, Fréquence: 0.1667
# Terme: uniform, Fréquence: 0.3333
# Terme: also, Fréquence: 0.1667
# Terme: exact, Fréquence: 0.3333
# Terme: neumann, Fréquence: 0.3333
# Terme: calcul, Fréquence: 1.1667
# Terme: non, Fréquence: 0.1667
# Terme: circulatori, Fréquence: 0.1667
# Terme: plane, Fréquence: 0.3333
# Terme: axial, Fréquence: 0.5000
# Terme: symmetr, Fréquence: 0.1667
# Terme: within, Fréquence: 0.3333
# Terme: arbitrari, Fréquence: 0.1667
# Terme: gener, Fréquence: 0.3333
# Terme: method, Fréquence: 0.8333
# Terme: solv, Fréquence: 0.6667
# Terme: second, Fréquence: 0.3333
# Terme: valu, Fréquence: 0.5000
# Terme: develop, Fréquence: 0.3333
# Terme: appli, Fréquence: 0.1667
# Terme: low, Fréquence: 0.5000
# Terme: almost, Fréquence: 0.1667
# Terme: shape, Fréquence: 0.3333
# Terme: provid, Fréquence: 0.1667
# Terme: either, Fréquence: 0.1667
# Terme: symmetri, Fréquence: 0.1667
# Terme: solid, Fréquence: 0.3333
# Terme: inlet, Fréquence: 0.1667
# Terme: pure, Fréquence: 0.1667
# Terme: intern, Fréquence: 0.1667
# Terme: capabl, Fréquence: 0.1667
# Terme: deal, Fréquence: 0.1667
# Terme: sever, Fréquence: 0.1667
# Terme: presenc, Fréquence: 0.1667
# Terme: one, Fréquence: 0.1667
# Terme: anoth, Fréquence: 0.1667
# Terme: interfer, Fréquence: 0.1667
# Terme: eas, Fréquence: 0.1667
# Terme: need, Fréquence: 0.3333
# Terme: involv, Fréquence: 0.1667
# Terme: area, Fréquence: 0.3333
# Terme: suction, Fréquence: 0.1667
# Terme: comput, Fréquence: 0.3333
# Terme: point, Fréquence: 0.5000
# Terme: surfac, Fréquence: 0.8333
# Terme: entir, Fréquence: 0.1667
# Terme: field, Fréquence: 0.3333
# Terme: sourc, Fréquence: 0.1667
# Terme: use, Fréquence: 0.6667
# Terme: fredholm, Fréquence: 0.1667
# Terme: kind, Fréquence: 0.1667
# Terme: set, Fréquence: 0.1667
# Terme: linear, Fréquence: 0.1667
# Terme: algebra, Fréquence: 0.1667
# Terme: modifi, Fréquence: 0.1667
# Terme: seidel, Fréquence: 0.1667
# Terme: time, Fréquence: 0.1667
# Terme: program, Fréquence: 0.1667
# Terme: ibm, Fréquence: 0.1667
# Terme: 704, Fréquence: 0.1667
# Terme: edpm, Fréquence: 0.1667
# Terme: previous, Fréquence: 0.1667
# Terme: mention, Fréquence: 0.1667
# Terme: characterist, Fréquence: 0.5000
# Terme: whose, Fréquence: 0.1667
# Terme: profil, Fréquence: 0.1667
# Terme: defin, Fréquence: 0.3333
# Terme: satisfactorili, Fréquence: 0.1667
# Terme: 300, Fréquence: 0.1667
# Terme: coordin, Fréquence: 0.1667
# Terme: number, Fréquence: 0.6667
# Terme: scope, Fréquence: 0.1667
# Terme: accuraci, Fréquence: 0.1667
# Terme: requir, Fréquence: 0.1667
# Terme: three, Fréquence: 0.1667
# Terme: minut, Fréquence: 0.1667
# Terme: hour, Fréquence: 0.1667
# Terme: depend, Fréquence: 0.3333
# Terme: upon, Fréquence: 0.1667
# Terme: secondari, Fréquence: 0.3333
# Terme: embed, Fréquence: 0.5000
# Terme: ramp, Fréquence: 0.3333
# Terme: compress, Fréquence: 0.3333
# Terme: locat, Fréquence: 0.3333
# Terme: local, Fréquence: 0.3333
# Terme: superson, Fréquence: 0.1667
# Terme: behind, Fréquence: 0.1667
# Terme: bow, Fréquence: 0.3333
# Terme: disturb, Fréquence: 0.1667
# Terme: may, Fréquence: 0.1667
# Terme: view, Fréquence: 0.1667
# Terme: newtonian, Fréquence: 1.1667
# Terme: impact, Fréquence: 0.1667
# Terme: thin, Fréquence: 0.1667
# Terme: examin, Fréquence: 0.1667
# Terme: applic, Fréquence: 0.1667
# Terme: cone, Fréquence: 0.3333
# Terme: wedg, Fréquence: 0.1667
# Terme: suggest, Fréquence: 0.1667
# Terme: expect, Fréquence: 0.1667
# Terme: give, Fréquence: 0.3333
# Terme: pressur, Fréquence: 2.3333
# Terme: base, Fréquence: 0.1667
# Terme: concept, Fréquence: 0.1667
# Terme: predict, Fréquence: 0.3333
# Terme: interest, Fréquence: 0.1667
# Terme: thing, Fréquence: 0.1667
# Terme: first, Fréquence: 0.1667
# Terme: factor, Fréquence: 0.1667
# Terme: 1, Fréquence: 0.6667
# Terme: 5, Fréquence: 0.5000
# Terme: 3, Fréquence: 0.3333
# Terme: exampl, Fréquence: 0.3333
# Terme: flare, Fréquence: 0.6667
# Terme: stabil, Fréquence: 0.3333
# Terme: blunt, Fréquence: 0.3333
# Terme: revolut, Fréquence: 0.1667
# Terme: lower, Fréquence: 0.1667
# Terme: diminish, Fréquence: 0.1667
# Terme: flight, Fréquence: 0.1667
# Terme: rang, Fréquence: 0.1667
# Terme: vari, Fréquence: 0.3333
# Terme: nonuniform, Fréquence: 0.1667
# Terme: incid, Fréquence: 0.1667
# Terme: case, Fréquence: 0.3333
# Terme: flap, Fréquence: 0.3333
# Terme: mount, Fréquence: 0.1667
# Terme: larg, Fréquence: 0.1667
# Terme: coeffici, Fréquence: 0.5000
# Terme: variabl, Fréquence: 0.1667
# Terme: entropi, Fréquence: 0.1667
# Terme: greater, Fréquence: 0.1667
# Terme: maximum, Fréquence: 0.1667
# Terme: occur, Fréquence: 0.1667
# Terme: process, Fréquence: 0.3333
# Terme: effici, Fréquence: 0.1667
# Terme: singl, Fréquence: 0.1667
# Terme: protrud, Fréquence: 0.1667
# Terme: main, Fréquence: 0.1667
# Terme: revert, Fréquence: 0.1667
# Terme: initi, Fréquence: 0.1667
# Terme: slope, Fréquence: 0.1667
# Terme: normal, Fréquence: 0.1667
# Terme: forc, Fréquence: 0.1667
# Terme: pitch, Fréquence: 0.1667
# Terme: moment, Fréquence: 0.1667
# Terme: simplest, Fréquence: 0.1667
# Terme: convent, Fréquence: 0.1667
# Terme: dynam, Fréquence: 0.3333
# Terme: take, Fréquence: 0.1667
# Terme: 0, Fréquence: 0.1667
# Terme: measur, Fréquence: 0.3333
# Terme: given, Fréquence: 0.1667
# Terme: travers, Fréquence: 0.1667
# Terme: 10, Fréquence: 0.1667
# Terme: per, Fréquence: 0.1667
# Terme: cent, Fréquence: 0.1667
# Terme: rae, Fréquence: 0.1667
# Terme: 101, Fréquence: 0.1667
# Terme: section, Fréquence: 0.1667
# Terme: reynold, Fréquence: 0.1667
# Terme: 6, Fréquence: 0.1667
# Terme: x10, Fréquence: 0.3333
# Terme: 2, Fréquence: 0.1667
# Terme: drag, Fréquence: 0.3333
# Terme: centr, Fréquence: 0.1667
# Terme: check, Fréquence: 0.1667
# Terme: growth, Fréquence: 0.1667
# Terme: turbul, Fréquence: 0.1667
# Terme: known, Fréquence: 0.3333
# Terme: conclud, Fréquence: 0.1667
# Terme: still, Fréquence: 0.1667
# Terme: littl, Fréquence: 0.1667
# Terme: refin, Fréquence: 0.1667
# Terme: accur, Fréquence: 0.1667
# Terme: enough, Fréquence: 0.1667
# Terme: center, Fréquence: 0.1667
# Terme: actual, Fréquence: 0.1667

# %%
import json
import os
from collections import Counter

# Fonction pour lire les termes dans le fichier descripteur
def lire_termes(fichier_descripteur):
    termes = []
    with open(fichier_descripteur, 'r', encoding='utf-8') as f:
        for ligne in f:
            _, terme = ligne.strip().split(' ', 1)
            termes.append(terme)
    return termes

# Fonction pour calculer les fréquences et le poids des termes
def calculer_frequence_et_poids(documents):
    termes_tous_docs = []  # Tous les termes de tous les documents
    occurrences_termes_par_doc = {}  # Occurrences par document

    # Étape 1 : Collecter les occurrences dans chaque document
    for doc in documents:
        fichier_descripteur = os.path.join(descripteur_path, f"{doc}_descripteur.txt")
        termes = lire_termes(fichier_descripteur)
        
        termes_tous_docs.extend(termes)
        occurrences_termes_par_doc[doc] = Counter(termes)

    # Total de documents
    total_docs = len(documents)

    # Calculer la fréquence totale dans tous les documents
    occurrences_totales = Counter(termes_tous_docs)

    # Initialiser les dictionnaires pour stocker les fréquences et les poids
    index_inverse = {
        'Porter': {}
    }

    # Étape 2 : Calculer les fréquences et le poids pour chaque terme
    for doc, termes_counts in occurrences_termes_par_doc.items():
        for terme, count in termes_counts.items():
            # Fréquence dans le document (count / total termes du document)
            freq_doc = count / sum(termes_counts.values())

            # Fréquence du terme dans la collection
            freq_collection = occurrences_totales[terme] / sum(occurrences_totales.values())

            # Calcul du poids (exemple avec TF-IDF)
            poids = freq_doc * (1 / freq_collection) if freq_collection != 0 else 0

            # Enregistrer les valeurs dans le dictionnaire
            if terme not in index_inverse['Porter']:
                index_inverse['Porter'][terme] = [0, 0, 0]
            
            index_inverse['Porter'][terme] = [freq_doc, freq_collection, poids]

    return index_inverse

# chemin vers les fichiers descripteurs
descripteur_path = '../Descripteurs/lancaster'
documents = [doc.replace('_descripteur.txt', '') for doc in os.listdir(descripteur_path) if doc.endswith('_descripteur.txt')]

# Calcul des fréquences et poids
index_inverse = calculer_frequence_et_poids(documents)

# Sauvegarder dans un fichier JSON
output_path = '../Inverse/index_inverse_termes.json'
with open(output_path, 'w', encoding='utf-8') as f:
    json.dump(index_inverse, f, ensure_ascii=False, indent=4)

print(f"Les résultats ont été sauvegardés dans {output_path}.")
# Out:
# Les résultats ont été sauvegardés dans ../Inverse/index_inverse_termes.json.

# %%
import math
import json
import os
from collections import Counter

# Fonction pour lire les termes dans le fichier descripteur
def lire_termes(fichier_descripteur):
    termes = []
    with open(fichier_descripteur, 'r', encoding='utf-8') as f:
        for ligne in f:
            _, terme = ligne.strip().split(' ', 1)
            termes.append(terme)
    return termes # return tout les terme par document



# Fonction pour calculer les fréquences et le poids des termes
def calculer_frequence_et_poids(documents):
    termes_tous_docs = []  # Tous les termes de tous les documents
    occurrences_termes_par_doc = {}  # Occurrences par document

    # Étape 1 : Collecter les occurrences dans chaque document
    for doc in documents:
        fichier_descripteur = os.path.join(descripteur_path, f"{doc}_descripteur.txt")
        termes = lire_termes(fichier_descripteur)
        
        termes_tous_docs.extend(termes)
        occurrences_termes_par_doc[doc] = Counter(termes)
        
        i=0
        for key , val in occurrences_termes_par_doc:
            print(f'key :{key} , value:{val}')
            i=+1
            if (i==10 ):
                break

    # Total de documents
    total_docs = len(documents)

    # Calculer le nombre de documents contenant chaque terme
    docs_contenant_terme = Counter(term for termes_counts in occurrences_termes_par_doc.values() for term in termes_counts)

    # Initialiser les dictionnaires pour stocker les fréquences et les poids
    index_inverse = {
        'Porter': {},
        'Lancaster': {}
    }

    # Étape 2 : Calculer les fréquences et le poids pour chaque terme
    for doc, termes_counts in occurrences_termes_par_doc.items():
        max_freq = max(termes_counts.values())  # fréquence maximale dans le document
        
        for terme, count in termes_counts.items():
            # Fréquence normalisée dans le document
            freq_doc = count / max_freq

            # Fréquence du terme dans tous les documents (TF-IDF)
            idf = math.log((total_docs / (docs_contenant_terme[terme] + 1)) + 1)

            # Calcul du poids
            poids = freq_doc * idf

            # Enregistrer les valeurs dans le dictionnaire
            if terme not in index_inverse['Porter']:
                index_inverse['Porter'][terme] = [0, 0, 0]
            
            index_inverse['Porter'][terme] = [freq_doc, docs_contenant_terme[terme] / total_docs, poids]

    return index_inverse




# Chemin vers les fichiers descripteurs
descripteur_path = '../Descripteurs/lancaster'

documents = [doc.replace('_descripteur.txt', '') for doc in os.listdir(descripteur_path) if doc.endswith('_descripteur.txt')]

# Calcul des fréquences et poids
index_inverse = calculer_frequence_et_poids(documents)

# Sauvegarder dans un fichier JSON
output_path = '../Inverse/index_inverse_termes.json'
with open(output_path, 'w', encoding='utf-8') as f:
    json.dump(index_inverse, f, ensure_ascii=False, indent=4)

print(f"Les résultats ont été sauvegardés dans {output_path}.")
# Out:
# Les résultats ont été sauvegardés dans ../Inverse/index_inverse_termes.json.
